# %% [markdown]
# # Assignment - 2 -> Exploratory Data Analysis (EDA)
#
#
# In this assignment, you'll get to practice some of the concepts and skills covered in EDA.
#
# As you go through this notebook, you will find a **???** in certain places. To complete this assignment, you must replace all the **???** with appropriate values, expressions or statements to ensure that the notebook runs properly end-to-end.
#
# Some things to keep in mind:
#
# * Do not change variable names, delete cells or disturb other existing code. It may cause problems during evaluation.
# * In some cases, you may need to add some code cells or new statements before or after the line of code containing the **???**.
# * Questions marked **(Optional)** will not be considered for evaluation, and can be skipped. They are for your learning.
#
#
# If you are stuck, you can ask for help on the Whatsapp group. Please do not use **ChatGPT or any other LLM to get solutions to the questions.**

# %%
import pandas as pd

# %% [markdown]
# In this assignment, we're going to analyze an operate on data from a CSV file. Let's begin by downloading the CSV file.

# %% [markdown]
# Let's load the data from the CSV file into a Pandas data frame.

# %% [markdown]
# **Link for datasets -> https://drive.google.com/drive/folders/1ZUqgIlOvUuuh1HHpV2yy2zYdkEvQAvjS?usp=sharing**

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia    38928341            64.83
# 1           Albania    Europe     2877800            78.57
# 2           Algeria    Africa    43851043            76.88
# 3           Andorra    Europe       77265            83.73
# 4            Angola    Africa    32866268            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia    97338583            75.40
# 206  Western Sahara    Africa      597330            70.26
# 207           Yemen      Asia    29825968            66.12
# 208          Zambia    Africa    18383956            63.89
# 209        Zimbabwe    Africa    14862927            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# **Q1: How many countries does the dataframe contain?**
#
# Hint: Use the `.shape` method.

# %%
num_countries = countries_df.shape[0]

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 210 countries in the dataset

# %% [markdown]
# **Q2: Retrieve a list of continents from the dataframe?**
#
# *Hint: Use the `.unique` method of a series.*

# %%
continents = countries_df['continent'].unique()

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **Q3: What is the total population of all the countries listed in this dataset?**

# %%
total_population =countries_df['population'].sum()

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %% [markdown]
# **Q: (Optional) What is the overall life expectancy across in the world?**
#
# *Hint: You'll need to take a weighted average of life expectancy using populations as weights.*

# %% [markdown]
# **Q4: Create a dataframe containing 10 countries with the highest population.**
#
# *Hint: Chain the `sort_values` and `head` methods.*

# %%
most_populous_df =countries_df.sort_values(by='population',ascending=False).head(10)

# %%
most_populous_df
# Out:
#           location      continent  population  life_expectancy  \
# 41           China           Asia  1439323774            76.91
# 90           India           Asia  1380004385            69.66
# 199  United States  North America   331002647            78.86
# 91       Indonesia           Asia   273523621            71.72
# 145       Pakistan           Asia   220892331            67.27
# 27          Brazil  South America   212559409            75.88
# 141        Nigeria         Africa   206139587            54.69
# 15      Bangladesh           Asia   164689383            72.59
# 157         Russia         Europe   145934460            72.58
# 125         Mexico  North America   128932753            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita
# 41                         4.34       15308.712
# 90                         0.53        6426.674
# 199                        2.77       54225.446
# 91                         1.04       11188.744
# ...

# %% [markdown]
# **Q5: Add a new column in `countries_df` to record the overall GDP per country (product of population & per capita GDP).**

# %%
countries_df['gdp'] = countries_df['population']*countries_df['gdp_per_capita']

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia    38928341            64.83
# 1           Albania    Europe     2877800            78.57
# 2           Algeria    Africa    43851043            76.88
# 3           Andorra    Europe       77265            83.73
# 4            Angola    Africa    32866268            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia    97338583            75.40
# 206  Western Sahara    Africa      597330            70.26
# 207           Yemen      Asia    29825968            66.12
# 208          Zambia    Africa    18383956            63.89
# 209        Zimbabwe    Africa    14862927            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                          0.50        1803.987  7.022622e+10
# 1                          2.89       11803.431  3.396791e+10
# 2                          1.90       13913.839  6.101364e+11
# ...

# %% [markdown]
# **Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.**

# %% [markdown]
# **Q6: Create a data frame that counts the number countries in each continent?**
#
# *Hint: Use `groupby`, select the `location` column and aggregate using `count`.*

# %%
country_counts_df = countries_df.groupby('continent')['location'].count()

# %%
country_counts_df
# Out:
# continent
# Africa           55
# Asia             47
# Europe           51
# North America    36
# Oceania           8
# South America    13
# Name: location, dtype: int64

# %% [markdown]
# **Q7: Create a data frame showing the total population of each continent.**
#
# *Hint: Use `groupby`, select the population column and aggregate using `sum`.*

# %%
continent_populations_df =countries_df.groupby('continent')['population'].sum()

# %%
continent_populations_df
# Out:
# continent
# Africa           1339423921
# Asia             4607388081
# Europe            748506210
# North America     591242473
# Oceania            40958320
# South America     430461090
# Name: population, dtype: int64

# %% [markdown]
# Let's download another CSV file containing overall Covid-19 stats for various countires, and read the data into another Pandas data frame.

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Q8: Count the number of countries for which the `total_tests` data is missing.**
#
# *Hint: Use the `.isna` method.*

# %%
total_tests_missing =covid_data_df['total_tests'].isna().sum()

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 122 countries.

# %% [markdown]
# Let's merge the two data frames, and compute some more metrics.
#
# **Q9: Merge `countries_df` with `covid_data_df` on the `location` column.**
#
# *Hint: Use the `.merge` method on `countries_df`.

# %%
combined_df =pd.merge(countries_df,covid_data_df)

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia    38928341            64.83
# 1           Albania    Europe     2877800            78.57
# 2           Algeria    Africa    43851043            76.88
# 3           Andorra    Europe       77265            83.73
# 4            Angola    Africa    32866268            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia    97338583            75.40
# 206  Western Sahara    Africa      597330            70.26
# 207           Yemen      Asia    29825968            66.12
# 208          Zambia    Africa    18383956            63.89
# 209        Zimbabwe    Africa    14862927            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Q10: Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df['tests_per_million'] = combined_df['total_tests'] * 1e6 / combined_df['population']

# %%
combined_df['cases_per_million'] = combined_df['total_cases']*1e6/combined_df['population']

# %%
combined_df['deaths_per_million'] = combined_df['total_deaths']*1e6/combined_df['population']

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia    38928341            64.83
# 1           Albania    Europe     2877800            78.57
# 2           Algeria    Africa    43851043            76.88
# 3           Andorra    Europe       77265            83.73
# 4            Angola    Africa    32866268            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia    97338583            75.40
# 206  Western Sahara    Africa      597330            70.26
# 207           Yemen      Asia    29825968            66.12
# 208          Zambia    Africa    18383956            63.89
# 209        Zimbabwe    Africa    14862927            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 0                          0.50        1803.987  7.022622e+10      38243.0
# 1                          2.89       11803.431  3.396791e+10       9728.0
# ...

# %% [markdown]
# **Q11: Create a dataframe with 10 countires that have highest number of tests per million people.**

# %%
highest_tests_df = combined_df.sort_values(by='tests_per_million',ascending=False).head(10)

# %%
highest_tests_df
# Out:
#                  location      continent  population  life_expectancy  \
# 197  United Arab Emirates           Asia     9890400            77.97
# 14                Bahrain           Asia     1701583            77.29
# 115            Luxembourg         Europe      625976            82.25
# 122                 Malta         Europe      441539            82.53
# 53                Denmark         Europe     5792203            80.90
# 96                 Israel           Asia     8655541            82.97
# 89                Iceland         Europe      341250            82.99
# 157                Russia         Europe   145934460            72.58
# 199         United States  North America   331002647            78.86
# 10              Australia        Oceania    25499881            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 197                       1.200       67293.483  6.655595e+11      71540.0
# ...

# %% [markdown]
# **Q12: Create a dataframe with 10 countires that have highest number of positive cases per million people.**

# %%
highest_cases_df = combined_df.sort_values(by='cases_per_million',ascending=False).head(10)

# %%
highest_cases_df
# Out:
#           location      continent  population  life_expectancy  \
# 155          Qatar           Asia     2881060            80.23
# 14         Bahrain           Asia     1701583            77.29
# 147         Panama  North America     4314768            78.51
# 40           Chile  South America    19116209            80.18
# 162     San Marino         Europe       33938            84.97
# 9            Aruba  North America      106766            76.29
# 105         Kuwait           Asia     4270563            75.49
# 150           Peru  South America    32971846            76.74
# 27          Brazil  South America   212559409            75.88
# 199  United States  North America   331002647            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp  total_cases  \
# 155                        1.20      116935.600  3.368985e+11     119206.0
# 14                         2.00       43290.705  7.366273e+10      52440.0
# ...

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists of "highest number of tests per million" and "highest number of cases per million".**

# %% [markdown]
# **Use the countries.csv dataset for the below questions**

# %% [markdown]
# **Q13: Split the data into training and test sets (80% training, 20% test split) and print the shapes of the training and test sets.**

# %%
from sklearn.model_selection import train_test_split
train_set, test_set=train_test_split(countries_df,test_size=0.2)
print('shape of training set: ',train_set.shape)
print('shape of testing set: ',test_set.shape)
# Out:
# shape of training set:  (168, 7)
# shape of testing set:  (42, 7)

# %% [markdown]
# **Q14: Identify columns with missing values.**
#
# **Decide how to handle missing values:**
#
#   **- Drop rows/columns with excessive missing values.***
#
#   **- Impute missing values for `hospital_beds_per_thousand` and `gdp_per_capita` using the median or mean.**

# %%
countries_df['hospital_beds_per_thousand']=countries_df['hospital_beds_per_thousand'].fillna(countries_df['hospital_beds_per_thousand'].mean())
countries_df['gdp_per_capita']=countries_df['gdp_per_capita'].fillna(countries_df['gdp_per_capita'].mean())
countries_df['gdp']=countries_df['population']*countries_df['gdp_per_capita']
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia    38928341            64.83
# 1           Albania    Europe     2877800            78.57
# 2           Algeria    Africa    43851043            76.88
# 3           Andorra    Europe       77265            83.73
# 4            Angola    Africa    32866268            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia    97338583            75.40
# 206  Western Sahara    Africa      597330            70.26
# 207           Yemen      Asia    29825968            66.12
# 208          Zambia    Africa    18383956            63.89
# 209        Zimbabwe    Africa    14862927            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita           gdp
# 0                      0.500000     1803.987000  7.022622e+10
# 1                      2.890000    11803.431000  3.396791e+10
# 2                      1.900000    13913.839000  6.101364e+11
# ...

# %% [markdown]
# **Q15: Encode the `continent` column using one-hot encoding.**
#
# **- Check the updated dataset to ensure encoding was applied correctly.**

# %%
x=countries_df['continent'].unique()
countries_df[[x]]=0
for i in range(countries_df.shape[0]):
  for j in x:
    if countries_df.loc[i,'continent'] == j:
      countries_df.loc[i,j] = 1
countries_df.drop(columns='continent',inplace=True)
countries_df
# Out:
#            location  population  life_expectancy  hospital_beds_per_thousand  \
# 0       Afghanistan    38928341            64.83                    0.500000
# 1           Albania     2877800            78.57                    2.890000
# 2           Algeria    43851043            76.88                    1.900000
# 3           Andorra       77265            83.73                    3.012671
# 4            Angola    32866268            61.15                    3.012671
# ..              ...         ...              ...                         ...
# 205         Vietnam    97338583            75.40                    2.600000
# 206  Western Sahara      597330            70.26                    3.012671
# 207           Yemen    29825968            66.12                    0.700000
# 208          Zambia    18383956            63.89                    2.000000
# 209        Zimbabwe    14862927            61.49                    1.700000
#
# ...

# %% [markdown]
# **Q16: Scale the numerical features (`population`, `life_expectancy`, `hospital_beds_per_thousand`, `gdp_per_capita`) using standardization or normalization.**
#
# **Display the summary statistics of the scaled features.**

# %%
import pandas as pd
from scipy import stats
countries_df['life_expectancy'] = countries_df['life_expectancy'].fillna(countries_df['life_expectancy'].mean())
scaled_data = {}
scaled_data['population'], _ = stats.boxcox(countries_df['population'])
scaled_data['life_expectancy'], _ = stats.boxcox(countries_df['life_expectancy'])
scaled_data['hospital_beds_per_thousand'], _ = stats.boxcox(countries_df['hospital_beds_per_thousand'])
scaled_data['gdp_per_capita'], _ = stats.boxcox(countries_df['gdp_per_capita'])
scaled_df = pd.DataFrame(scaled_data)
summary_statistics = scaled_df.describe()
print(summary_statistics)
# Out:
#        population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# count  210.000000     2.100000e+02                  210.000000      210.000000
# mean    36.545765     6.081580e+06                    1.071957       35.188998
# std     10.724808     2.167294e+06                    0.963265        9.833594
# min      9.445329     1.615730e+06                   -1.666922       15.232585
# 25%     29.292930     4.610696e+06                    0.430935       27.924044
# 50%     37.361977     6.233014e+06                    1.302353       36.688024
# 75%     43.960031     7.601728e+06                    1.476253       41.352692
# max     69.875959     1.103176e+07                    3.977607       61.081382

# %% [markdown]
# **Q17: Create the following visualizations:**
#
#   **- A bar plot showing the number of countries in each continent.**
#
#   **- A scatter plot of `gdp_per_capita` vs. `life_expectancy`.**
#
#   **- A histogram of `population` (log-scaled if necessary).**
#
#  **- A heatmap to visualize correlations between numerical features.**

# %%
import numpy as np
import matplotlib.pyplot as plt
countries_df=pd.read_csv('countries.csv')
countries_df['continent'].value_counts().plot(kind='bar')
plt.title('Number of countries in each continent')
plt.xlabel('Continent')
plt.ylabel('Number of countries')
plt.show()
plt.scatter(countries_df['gdp_per_capita'], countries_df['life_expectancy'])
plt.title('GDP per capita vs life expectancy')
plt.xlabel('GDP per capita')
plt.ylabel('Life expectancy')
plt.show()
plt.hist(countries_df['population'], bins=30)
plt.yscale('log')
plt.title('Population Distribution')
plt.xlabel('Population')
plt.ylabel('Frequency (log scaled)')
plt.show()
a=['population', 'life_expectancy', 'hospital_beds_per_thousand', 'gdp_per_capita']
correlation_matrix = countries_df[a].corr()
plt.matshow(correlation_matrix, fignum=1, cmap='coolwarm')
plt.colorbar()
plt.xticks(range(len(a)), a, rotation=90)
plt.yticks(range(len(a)), a)
plt.title('Correlation heatmap of numerical features')
plt.show()

# %% [markdown]
# ## Submission
#
# Congratulations on making it this far! You've reached the end of this assignment, and you just completed your first real-world data analysis problem.
